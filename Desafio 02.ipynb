# %% [markdown]
# ### importando bibliotecas

# %%
import cv2, pandas as pd, numpy as np, matplotlib.pyplot as plt

# %% [markdown]
# ### Desafio
#
# São dadas duas imagens separadas a imagem `python.jpg` e a `imagem opencv-logo.png`
#
# Você precisa colocar a imagem uma sobre a outra conforme imagem:
#
# **Exemplo**
# ![Exemplo de solução](images/python-resposta.jpg)

# %% [markdown]
# ### Lendo imagens e verificando dimensões

# %%
def plot_img(img, title = "", cmap = None, figsize= (8,6)):
    plt.figure(figsize = figsize)
    plt.imshow(img, cmap = cmap, vmin = 0, vmax = 255)
    plt.title(title, fontdict = {'fontsize': 22})
    plt.xticks([])
    plt.yticks([])

# %%
python_img = cv2.imread('images/python.jpg', cv2.IMREAD_COLOR)
python_img = cv2.cvtColor(python_img, cv2.COLOR_BGR2RGB)

plot_img(python_img, 'python')

# %%
python_img.shape
# Out:
# (579, 1024, 3)

# %%
logo_img = cv2.imread('images/opencv-logo.png', cv2.IMREAD_COLOR)
logo_img = cv2.cvtColor(logo_img, cv2.COLOR_BGR2RGB)

plot_img(logo_img, 'logo_img')

# %%
logo_img.shape
# Out:
# (260, 220, 3)

# %% [markdown]
# ### Criando mascaras

# %%
mask_python = np.ones(python_img.shape[:2], np.uint8) * 255

# %%
mask_python[:260,:220] = np.zeros(logo_img.shape[:2], np.uint8)

# %%
plot_img(mask_python,'máscara', cmap = 'gray')

# %%
img_bg = cv2.bitwise_and(python_img, python_img, mask=mask_white)

# %%
plot_img(img_bg)

# %%
mask_black = np.zeros(python_img.shape[:3], np.uint8)
mask_black[:260,:220,:] = logo_img

# %%
plot_img(mask_black, 'logo')

# %%
mask_black.shape
# Out:
# (579, 1024, 3)

# %%
img_bg.shape
# Out:
# (579, 1024, 3)

# %%
img_final = cv2.add(mask_black, img_bg)

# %%
plot_img(img_final, 'Imagem Final', figsize = (16,8))
